# %%
import pandas as pd
import numpy as np

# %%
csvfile=pd.read_csv('housing.csv')
csvfile.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
tsvfile=pd.read_table('housing.tsv')
tsvfile.head()
# Out:
#   longitude,latitude,housing_median_age,total_rooms,total_bedrooms,populatio  \
# 0  n,households,median_income,median_house_value,...
# 1  - 122.23,37.88,41.0,880.0,129.0,322.0,126.0,8....
# 2  - 122.22,37.86,21.0,7099.0,1106.0,2401.0,1138....
# 3                                 - 122.24,37.85,52.
# 4                                           - 122.25
#
#    Unnamed: 1                                 Unnamed: 2     Unnamed: 3
# 0         NaN                                        NaN            NaN
# 1         NaN                                        NaN      ,NEAR BAY
# 2         NaN                                        NaN  00.0,NEAR BAY
# 3         NaN  0,1467.0,190.0,496.0,177.0,7.2574,352100.     0,NEAR BAY
# 4  ,37.85,52.  0,1274.0,235.0,558.0,219.0,5.6431,341300.     0,NEAR BAY

# %%
exfile=pd.read_excel('housing.xlsx')
exfile.head()
# Out:
#   longitude,latitude,housing_median_age,total_rooms,total_bedrooms,populatio  \
# 0  n,households,median_income,median_house_value,...
# 1  - 122.23,37.88,41.0,880.0,129.0,322.0,126.0,8....
# 2  - 122.22,37.86,21.0,7099.0,1106.0,2401.0,1138....
# 3                                 - 122.24,37.85,52.
# 4                                           - 122.25
#
#    Unnamed: 1                                 Unnamed: 2     Unnamed: 3
# 0         NaN                                        NaN            NaN
# 1         NaN                                        NaN      ,NEAR BAY
# 2         NaN                                        NaN  00.0,NEAR BAY
# 3         NaN  0,1467.0,190.0,496.0,177.0,7.2574,352100.     0,NEAR BAY
# 4  ,37.85,52.  0,1274.0,235.0,558.0,219.0,5.6431,341300.     0,NEAR BAY

# %%
csvfile.longitude.unique()
# Out:
# array([-122.23, -122.22, -122.24, -122.25, -122.26, -122.27, -122.28,
#        -122.29, -122.3 , -122.21, -122.2 , -122.19, -122.18, -122.13,
#        -122.16, -122.17, -122.15, -122.14, -122.12, -122.33, -122.34,
#        -122.06, -122.07, -122.08, -122.09, -122.1 , -122.11, -122.03,
#        -121.97, -122.02, -122.04, -122.05, -121.99, -122.01, -121.96,
#        -121.98, -122.  , -121.93, -121.94, -121.95, -121.92, -121.89,
#        -121.91, -121.9 , -121.88, -121.87, -121.85, -121.86, -121.84,
#        -121.82, -121.77, -121.62, -121.61, -121.72, -121.73, -121.75,
#        -121.8 , -121.76, -121.78, -121.79, -119.78, -119.93, -120.  ,
#        -120.56, -120.59, -120.55, -120.25, -120.79, -120.8 , -120.65,
#        -120.76, -120.88, -120.69, -120.93, -120.97, -120.87, -120.98,
#        -120.72, -120.77, -120.66, -120.62, -120.71, -121.83, -121.81,
#        -121.74, -121.68, -121.54, -121.51, -121.59, -121.58, -121.6 ,
# ...

# %%
csvfile.loc[0]
# Out:
# longitude              -122.23
# latitude                 37.88
# housing_median_age          41
# total_rooms                880
# total_bedrooms             129
# population                 322
# households                 126
# median_income           8.3252
# median_house_value      452600
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object

# %%
csvfile.iloc[3,:]
# Out:
# longitude              -122.25
# latitude                 37.85
# housing_median_age          52
# total_rooms               1274
# total_bedrooms             235
# population                 558
# households                 219
# median_income           5.6431
# median_house_value      341300
# ocean_proximity       NEAR BAY
# Name: 3, dtype: object

# %%
csvfile.rename(index={0: "x",1: "y", 2: "z"})
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# x        -122.23     37.88                  41          880           129.0
# y        -122.22     37.86                  21         7099          1106.0
# z        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# 5        -122.25     37.85                  52          919           213.0
# 6        -122.25     37.84                  52         2535           489.0
# 7        -122.25     37.84                  52         3104           687.0
# 8        -122.26     37.84                  42         2555           665.0
# 9        -122.25     37.84                  52         3549           707.0
# 10       -122.26     37.85                  52         2202           434.0
# ...

# %%
csvfile.rename(index=lambda x:x+1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        -122.23     37.88                  41          880           129.0
# 2        -122.22     37.86                  21         7099          1106.0
# 3        -122.24     37.85                  52         1467           190.0
# 4        -122.25     37.85                  52         1274           235.0
# 5        -122.25     37.85                  52         1627           280.0
# 6        -122.25     37.85                  52          919           213.0
# 7        -122.25     37.84                  52         2535           489.0
# 8        -122.25     37.84                  52         3104           687.0
# 9        -122.26     37.84                  42         2555           665.0
# 10       -122.25     37.84                  52         3549           707.0
# 11       -122.26     37.85                  52         2202           434.0
# ...

# %%
csvfile.pivot_table(index="total_rooms",values=["total_bedrooms","population"],aggfunc=np.sum)
# Out:
#              population  total_bedrooms
# total_rooms
# 2                     6             2.0
# 6                     8             2.0
# 8                    13             1.0
# 11                   24            11.0
# 12                   18             4.0
# 15                   26             8.0
# 16                    8             4.0
# 18                   24            16.0
# 19                 7626            24.0
# 20                   89             9.0
# 21                   21             7.0
# 22                   87            18.0
# 24                   69            12.0
# 25                   27            10.0
# 26                   87            17.0
# 28                    9             4.0
# 30                   62             7.0
# 32                  199            46.0
# 36                 4233            17.0
# 37                   34            11.0
# 38                   66             8.0
# 40                  464            46.0
# ...

# %%
csvfile.sort_values("population")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5342     -118.44     34.04                  16           18             6.0
# 12458    -114.62     33.62                  26           18             3.0
# 3126     -117.79     35.21                   4            2             2.0
# 12286    -116.95     33.86                   1            6             2.0
# 18210    -122.06     37.39                  26           18             4.0
# 3125     -117.76     35.22                   4           18             3.0
# 14822    -117.12     32.66                  52           16             4.0
# 19389    -120.85     37.75                  26           28             4.0
# 13979    -116.76     34.14                   4           42            10.0
# 16888    -122.37     37.60                  26           15             3.0
# 16171    -122.50     37.79                  52            8             1.0
# ...

# %%
csvfile[csvfile["population"]>12000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 922      -121.92     37.53                   7        28258          3864.0
# 6057     -117.78     34.03                   8        32054          5290.0
# 6066     -117.87     34.04                   7        27700          4179.0
# 9019     -118.78     34.16                   9        30405          4093.0
# 9744     -121.68     36.72                  12        19234          4492.0
# 9880     -121.79     36.64                  11        32627          6445.0
# 10309    -117.74     33.89                   4        37937          5471.0
# 12215    -117.12     33.52                   4        30401          4957.0
# 13139    -121.44     38.43                   3        39320          6210.0
# 15360    -117.42     33.35                  14        25135          4819.0
# 17413    -120.59     34.70                  29        17738          3114.0
#
# ...

# %%
csvfile.groupby("housing_median_age")
csvfile
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# 5        -122.25     37.85                  52          919           213.0
# 6        -122.25     37.84                  52         2535           489.0
# 7        -122.25     37.84                  52         3104           687.0
# 8        -122.26     37.84                  42         2555           665.0
# 9        -122.25     37.84                  52         3549           707.0
# 10       -122.26     37.85                  52         2202           434.0
# ...

# %%
csvfile.groupby(["longitude","latitude"])
csvfile
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# 5        -122.25     37.85                  52          919           213.0
# 6        -122.25     37.84                  52         2535           489.0
# 7        -122.25     37.84                  52         3104           687.0
# 8        -122.26     37.84                  42         2555           665.0
# 9        -122.25     37.84                  52         3549           707.0
# 10       -122.26     37.85                  52         2202           434.0
# ...

# %%
csvfile['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
csvfile.rename(columns={'housing_median_age':'House_Median_Age'},inplace=True)
csvfile
# Out:
#        longitude  latitude  House_Median_Age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41          880           129.0
# 1        -122.22     37.86                21         7099          1106.0
# 2        -122.24     37.85                52         1467           190.0
# 3        -122.25     37.85                52         1274           235.0
# 4        -122.25     37.85                52         1627           280.0
# 5        -122.25     37.85                52          919           213.0
# 6        -122.25     37.84                52         2535           489.0
# 7        -122.25     37.84                52         3104           687.0
# 8        -122.26     37.84                42         2555           665.0
# 9        -122.25     37.84                52         3549           707.0
# 10       -122.26     37.85                52         2202           434.0
# 11       -122.26     37.85                52         3503           752.0
# ...

# %%
jsonfile=pd.read_json(r'C:\Users\PRATHYUSHA\Desktop\DS\Lab\housejson')
jsonfile
# Out:
#        households  housing_median_age  latitude  longitude  \
# 0             126                  41     37.88    -122.23
# 1            1138                  21     37.86    -122.22
# 2             177                  52     37.85    -122.24
# 3             219                  52     37.85    -122.25
# 4             259                  52     37.85    -122.25
# 5             193                  52     37.85    -122.25
# 6             514                  52     37.84    -122.25
# 7             647                  52     37.84    -122.25
# 8             595                  42     37.84    -122.26
# 9             714                  52     37.84    -122.25
# 10            402                  52     37.85    -122.26
# 11            734                  52     37.85    -122.26
# 12            468                  52     37.85    -122.26
# 13            174                  52     37.84    -122.26
# 14            620                  52     37.85    -122.26
# ...

# %%
csvfile.apply(pd.Series.value_counts)
# Out:
#             longitude  latitude  House_Median_Age  total_rooms  \
# -124.35           1.0       NaN               NaN          NaN
# -124.3            2.0       NaN               NaN          NaN
# -124.27           1.0       NaN               NaN          NaN
# -124.26           1.0       NaN               NaN          NaN
# -124.25           1.0       NaN               NaN          NaN
# -124.23           3.0       NaN               NaN          NaN
# -124.22           1.0       NaN               NaN          NaN
# -124.21           3.0       NaN               NaN          NaN
# -124.19           4.0       NaN               NaN          NaN
# -124.18           6.0       NaN               NaN          NaN
# -124.17          12.0       NaN               NaN          NaN
# -124.16          15.0       NaN               NaN          NaN
# -124.15           9.0       NaN               NaN          NaN
# -124.14          13.0       NaN               NaN          NaN
# ...

# %%
csvfile.values.tolist()
# Out:
# [[-122.23, 37.88, 41L, 880L, 129.0, 322L, 126L, 8.3252, 452600L, 'NEAR BAY'],
#  [-122.22,
#   37.86,
#   21L,
#   7099L,
#   1106.0,
#   2401L,
#   1138L,
#   8.3014,
#   358500L,
#   'NEAR BAY'],
#  [-122.24, 37.85, 52L, 1467L, 190.0, 496L, 177L, 7.2574, 352100L, 'NEAR BAY'],
#  [-122.25, 37.85, 52L, 1274L, 235.0, 558L, 219L, 5.6431, 341300L, 'NEAR BAY'],
#  [-122.25, 37.85, 52L, 1627L, 280.0, 565L, 259L, 3.8462, 342200L, 'NEAR BAY'],
#  [-122.25, 37.85, 52L, 919L, 213.0, 413L, 193L, 4.0368, 269700L, 'NEAR BAY'],
#  [-122.25, 37.84, 52L, 2535L, 489.0, 1094L, 514L, 3.6591, 299200L, 'NEAR BAY'],
#  [-122.25, 37.84, 52L, 3104L, 687.0, 1157L, 647L, 3.12, 241400L, 'NEAR BAY'],
#  [-122.26, 37.84, 42L, 2555L, 665.0, 1206L, 595L, 2.0804, 226700L, 'NEAR BAY'],
#  [-122.25, 37.84, 52L, 3549L, 707.0, 1551L, 714L, 3.6912, 261100L, 'NEAR BAY'],
#  [-122.26, 37.85, 52L, 2202L, 434.0, 910L, 402L, 3.2031, 281500L, 'NEAR BAY'],
# ...
