# %% [markdown]
# # Practical 2

# %%
import pandas as pd

# %%
import io
data = io.StringIO('''Fruit,Color,Count,Price
Apple,Red,3,$1.29
Apple,Green,9,$0.99
Pear,Red,25,$2.59
Pear,Green,26,$2.79
Lime,Green,99,$0.39
''')

# %%
df=pd.read_csv(data)
df
# Out:
#    Fruit  Color  Count  Price
# 0  Apple    Red      3  $1.29
# 1  Apple  Green      9  $0.99
# 2   Pear    Red     25  $2.59
# 3   Pear  Green     26  $2.79
# 4   Lime  Green     99  $0.39

# %%
df.T
# Out:
#            0      1      2      3      4
# Fruit  Apple  Apple   Pear   Pear   Lime
# Color    Red  Green    Red  Green  Green
# Count      3      9     25     26     99
# Price  $1.29  $0.99  $2.59  $2.79  $0.39

# %%
df.T.T
# Out:
#    Fruit  Color Count  Price
# 0  Apple    Red     3  $1.29
# 1  Apple  Green     9  $0.99
# 2   Pear    Red    25  $2.59
# 3   Pear  Green    26  $2.79
# 4   Lime  Green    99  $0.39

# %%
df=df.append({"Fruit":"mango","Color":"Yellow","Count":50,"Price":"$0.5"},ignore_index=True)

# %%
df["CSI (OUT OF 10)"]=[8.8,8.2,8.6,8.4,7.8,9.0]

# %%
df
# Out:
#    Fruit   Color  Count  Price  CSI (OUT OF 10)
# 0  Apple     Red      3  $1.29              8.8
# 1  Apple   Green      9  $0.99              8.2
# 2   Pear     Red     25  $2.59              8.6
# 3   Pear   Green     26  $2.79              8.4
# 4   Lime   Green     99  $0.39              7.8
# 5  mango  Yellow     50   $0.5              9.0

# %%
df.sort_values("Price",ascending=True)
# Out:
#    Fruit   Color  Count  Price  CSI (OUT OF 10)
# 4   Lime   Green     99  $0.39              7.8
# 5  mango  Yellow     50   $0.5              9.0
# 1  Apple   Green      9  $0.99              8.2
# 0  Apple     Red      3  $1.29              8.8
# 2   Pear     Red     25  $2.59              8.6
# 3   Pear   Green     26  $2.79              8.4

# %%
df.sort_index()
# Out:
#    Fruit   Color  Count  Price  CSI (OUT OF 10)
# 0  Apple     Red      3  $1.29              8.8
# 1  Apple   Green      9  $0.99              8.2
# 2   Pear     Red     25  $2.59              8.6
# 3   Pear   Green     26  $2.79              8.4
# 4   Lime   Green     99  $0.39              7.8
# 5  mango  Yellow     50   $0.5              9.0

# %%
df
# Out:
#    Fruit   Color  Count  Price  CSI (OUT OF 10)
# 0  Apple     Red      3  $1.29              8.8
# 1  Apple   Green      9  $0.99              8.2
# 2   Pear     Red     25  $2.59              8.6
# 3   Pear   Green     26  $2.79              8.4
# 4   Lime   Green     99  $0.39              7.8
# 5  mango  Yellow     50   $0.5              9.0

# %%
df.set_index("Fruit",inplace=True)

# %%
df
# Out:
#         Color  Count  Price  CSI (OUT OF 10)
# Fruit
# Apple     Red      3  $1.29              8.8
# Apple   Green      9  $0.99              8.2
# Pear      Red     25  $2.59              8.6
# Pear    Green     26  $2.79              8.4
# Lime    Green     99  $0.39              7.8
# mango  Yellow     50   $0.5              9.0

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    Fruit   Color  Count  Price  CSI (OUT OF 10)
# 0  Apple     Red      3  $1.29              8.8
# 1  Apple   Green      9  $0.99              8.2
# 2   Pear     Red     25  $2.59              8.6
# 3   Pear   Green     26  $2.79              8.4
# 4   Lime   Green     99  $0.39              7.8
# 5  mango  Yellow     50   $0.5              9.0

# %%
df.drop("Count",inplace=True,axis=1)
df
# Out:
#    Fruit   Color  Price  CSI (OUT OF 10)
# 0  Apple     Red  $1.29              8.8
# 1  Apple   Green  $0.99              8.2
# 2   Pear     Red  $2.59              8.6
# 3   Pear   Green  $2.79              8.4
# 4   Lime   Green  $0.39              7.8
# 5  mango  Yellow   $0.5              9.0

# %%
df[df["CSI (OUT OF 10)"]>8.5]
# Out:
#    Fruit   Color  Price  CSI (OUT OF 10)
# 0  Apple     Red  $1.29              8.8
# 2   Pear     Red  $2.59              8.6
# 5  mango  Yellow   $0.5              9.0

# %%
df
# Out:
#    Fruit   Color  Price  CSI (OUT OF 10)
# 0  Apple     Red  $1.29              8.8
# 1  Apple   Green  $0.99              8.2
# 2   Pear     Red  $2.59              8.6
# 3   Pear   Green  $2.79              8.4
# 4   Lime   Green  $0.39              7.8
# 5  mango  Yellow   $0.5              9.0

# %%
df.drop_duplicates(subset ="Fruit", keep ="first", inplace = True)

# %%
df
# Out:
#    Fruit   Color  Price  CSI (OUT OF 10)
# 0  Apple     Red  $1.29              8.8
# 2   Pear     Red  $2.59              8.6
# 4   Lime   Green  $0.39              7.8
# 5  mango  Yellow   $0.5              9.0

# %%
n=int(input("enter a number"))
# Out:
# enter a number 2

# %%
df.head(n)
# Out:
#    Fruit Color  Price  CSI (OUT OF 10)
# 0  Apple   Red  $1.29              8.8
# 2   Pear   Red  $2.59              8.6

# %%
df.tail(n)
# Out:
#    Fruit   Color  Price  CSI (OUT OF 10)
# 4   Lime   Green  $0.39              7.8
# 5  mango  Yellow   $0.5              9.0

# %%
df
# Out:
#    Fruit   Color  Price  CSI (OUT OF 10)
# 0  Apple     Red  $1.29              8.8
# 2   Pear     Red  $2.59              8.6
# 4   Lime   Green  $0.39              7.8
# 5  mango  Yellow   $0.5              9.0

# %%
df["Fruit"]
# Out:
# 0    Apple
# 2     Pear
# 4     Lime
# 5    mango
# Name: Fruit, dtype: object

# %%
df=df[["Fruit","Color","Price"]]

# %%
df
# Out:
#    Fruit   Color  Price
# 0  Apple     Red  $1.29
# 2   Pear     Red  $2.59
# 4   Lime   Green  $0.39
# 5  mango  Yellow   $0.5

# %%
df.reset_index(inplace=True,drop=True)
df
# Out:
#    Fruit   Color  Price
# 0  Apple     Red  $1.29
# 1   Pear     Red  $2.59
# 2   Lime   Green  $0.39
# 3  mango  Yellow   $0.5

# %%
tdf=df[:1]+df[1:]

# %%
tdf
# Out:
#   Fruit Color Price
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN

# %%
df
# Out:
#    Fruit   Color  Price
# 0  Apple     Red  $1.29
# 1   Pear     Red  $2.59
# 2   Lime   Green  $0.39
# 3  mango  Yellow   $0.5

# %%
df.describe()
# Out:
#        Fruit Color  Price
# count      4     4      4
# unique     4     3      4
# top     Lime   Red  $1.29
# freq       1     2      1

# %%
df
# Out:
#    Fruit   Color  Price
# 0  Apple     Red  $1.29
# 1   Pear     Red  $2.59
# 2   Lime   Green  $0.39
# 3  mango  Yellow   $0.5

# %%
df["Count"]=[5,4,3,4]

# %%
df
# Out:
#    Fruit   Color  Price  Count
# 0  Apple     Red  $1.29      5
# 1   Pear     Red  $2.59      4
# 2   Lime   Green  $0.39      3
# 3  mango  Yellow   $0.5      4

# %%
df2 = pd.DataFrame({'id': ['A01', 'A02', 'A03', 'A04'],'Name': ['ABC', 'PQR', 'DEF', 'GHI']}) 
  
df3 = pd.DataFrame({'City': ['MUMBAI', 'PUNE', 'MUMBAI', 'DELHI'],'Age': ['12', '13', '14', '12']})

# %%
df2
# Out:
#     id Name
# 0  A01  ABC
# 1  A02  PQR
# 2  A03  DEF
# 3  A04  GHI

# %%
df3
# Out:
#      City Age
# 0  MUMBAI  12
# 1    PUNE  13
# 2  MUMBAI  14
# 3   DELHI  12

# %%
pd.concat([df2, df3], axis=1, join='inner')
# Out:
#     id Name    City Age
# 0  A01  ABC  MUMBAI  12
# 1  A02  PQR    PUNE  13
# 2  A03  DEF  MUMBAI  14
# 3  A04  GHI   DELHI  12

# %%
ndf=pd.DataFrame({'id': [None, None, None, None],'Name': [None, 'PQR', 'DEF', 'GHI'],'City': [None, 'PUNE', 'MUMBAI', 'DELHI'],'Age': [None, '13', '14', None]})

# %%
ndf
# Out:
#      id  Name    City   Age
# 0  None  None    None  None
# 1  None   PQR    PUNE    13
# 2  None   DEF  MUMBAI    14
# 3  None   GHI   DELHI  None

# %%
ndf.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
ndf=pd.DataFrame({'id': [None, None, None, None],'Name': [None, 'PQR', 'DEF', 'GHI'],'City': [None, 'PUNE', 'MUMBAI', 'DELHI'],'Age': [None, '13', '14', None]})

# %%
ndf
# Out:
#      id  Name    City   Age
# 0  None  None    None  None
# 1  None   PQR    PUNE    13
# 2  None   DEF  MUMBAI    14
# 3  None   GHI   DELHI  None

# %%
ndf.fillna(method ='ffill', inplace = True)

# %%
ndf
# Out:
#      id  Name    City   Age
# 0  None  None    None  None
# 1  None   PQR    PUNE    13
# 2  None   DEF  MUMBAI    14
# 3  None   GHI   DELHI    14
