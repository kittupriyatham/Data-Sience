# %% [markdown]
# # Skilling 3

# %%
import pandas as pd

# %%
df=pd.read_csv('Hospital General Information.csv', encoding="ISO-8859-1")
df
# Out:
#       Provider ID                     Hospital Name  \
# 0           10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1           10005     MARSHALL MEDICAL CENTER SOUTH
# 2           10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3           10007          MIZELL MEMORIAL HOSPITAL
# 4           10008       CRENSHAW COMMUNITY HOSPITAL
# ...           ...                               ...
# 4807       670118              FIRST TEXAS HOSPITAL
# 4808       640001       LBJ TROPICAL MEDICAL CENTER
# 4809       650001  GUAM MEMORIAL HOSPITAL AUTHORITY
# 4810       650003        GUAM REGIONAL MEDICAL CITY
# 4811       660001        COMMONWEALTH HEALTH CENTER
#
#                             Address       City State  ZIP Code County Name  \
# 0            1108 ROSS CLARK CIRCLE     DOTHAN    AL     36301     HOUSTON
# 1        2505 U S HIGHWAY 431 NORTH       BOAZ    AL     35957    MARSHALL
# 2                205 MARENGO STREET   FLORENCE    AL     35631  LAUDERDALE
# ...

# %%
df=df.fillna(method='ffill')

# %%
df
# Out:
#       Provider ID                     Hospital Name  \
# 0           10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1           10005     MARSHALL MEDICAL CENTER SOUTH
# 2           10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3           10007          MIZELL MEMORIAL HOSPITAL
# 4           10008       CRENSHAW COMMUNITY HOSPITAL
# ...           ...                               ...
# 4807       670118              FIRST TEXAS HOSPITAL
# 4808       640001       LBJ TROPICAL MEDICAL CENTER
# 4809       650001  GUAM MEMORIAL HOSPITAL AUTHORITY
# 4810       650003        GUAM REGIONAL MEDICAL CITY
# 4811       660001        COMMONWEALTH HEALTH CENTER
#
#                             Address       City State  ZIP Code County Name  \
# 0            1108 ROSS CLARK CIRCLE     DOTHAN    AL     36301     HOUSTON
# 1        2505 U S HIGHWAY 431 NORTH       BOAZ    AL     35957    MARSHALL
# 2                205 MARENGO STREET   FLORENCE    AL     35631  LAUDERDALE
# ...

# %%
df.head()
# Out:
#    Provider ID                     Hospital Name                     Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        10005     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2        10006    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3        10007          MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4        10008       CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#        City State  ZIP Code County Name  Phone Number         Hospital Type  \
# 0    DOTHAN    AL     36301     HOUSTON    3347938701  Acute Care Hospitals
# 1      BOAZ    AL     35957    MARSHALL    2565938310  Acute Care Hospitals
# 2  FLORENCE    AL     35631  LAUDERDALE    2567688400  Acute Care Hospitals
# 3       OPP    AL     36467   COVINGTON    3344933541  Acute Care Hospitals
# 4   LUVERNE    AL     36049    CRENSHAW    3343353374  Acute Care Hospitals
#
# ...

# %%
df[["Hospital Type","Hospital Ownership"]]
# Out:
#              Hospital Type                           Hospital Ownership
# 0     Acute Care Hospitals  Government - Hospital District or Authority
# 1     Acute Care Hospitals  Government - Hospital District or Authority
# 2     Acute Care Hospitals  Government - Hospital District or Authority
# 3     Acute Care Hospitals               Voluntary non-profit - Private
# 4     Acute Care Hospitals                                  Proprietary
# ...                    ...                                          ...
# 4807  Acute Care Hospitals                                  Proprietary
# 4808  Acute Care Hospitals  Government - Hospital District or Authority
# 4809  Acute Care Hospitals                           Government - Local
# 4810  Acute Care Hospitals               Voluntary non-profit - Private
# 4811  Acute Care Hospitals                                  Proprietary
#
# [4812 rows x 2 columns]

# %%
df[["Hospital Type","Hospital Ownership"]].describe()
# Out:
#                Hospital Type              Hospital Ownership
# count                   4812                            4812
# unique                     3                              10
# top     Acute Care Hospitals  Voluntary non-profit - Private
# freq                    3369                            2052

# %%
df["State"].value_counts(sort=True, ascending=True)
# Out:
# AS      1
# MP      1
# GU      2
# VI      2
# DE      7
# DC      8
# RI     11
# VT     14
# AK     22
# HI     23
# NH     26
# WY     28
# CT     31
# ME     33
# NV     35
# NM     41
# ID     41
# ND     44
# UT     46
# MD     49
# WV     49
# PR     52
# OR     60
# SC     60
# SD     60
# MT     62
# MA     64
# NJ     66
# AR     75
# CO     78
# AZ     80
# VA     86
# NE     89
# AL     90
# WA     91
# KY     94
# MS     95
# TN    107
# NC    107
# MO    112
# IA    116
# IN    120
# LA    121
# OK    124
# WI    126
# MN    131
# MI    131
# GA    133
# KS    137
# OH    168
# NY    171
# PA    171
# IL    180
# FL    187
# CA    343
# TX    411
# Name: State, dtype: int64

# %%
df[df["State"]=="TX"][["State","County Name","Provider ID"]]
# Out:
#      State County Name  Provider ID
# 3954    TX     EL PASO       450002
# 3955    TX        KERR       450007
# 3956    TX     WICHITA       450010
# 3957    TX      BRAZOS       450011
# 3958    TX      DALLAS       450015
# ...    ...         ...          ...
# 4803    TX    COLORADO       670114
# 4804    TX     LIBERTY       670115
# 4805    TX     TARRANT       670116
# 4806    TX   VAN ZANDT       670117
# 4807    TX      HARRIS       670118
#
# [411 rows x 3 columns]

# %%
df[df["State"]=="TX"][["State","Hospital Type","Hospital Ownership"]]
# Out:
#      State         Hospital Type                           Hospital Ownership
# 3954    TX  Acute Care Hospitals                                  Proprietary
# 3955    TX  Acute Care Hospitals               Voluntary non-profit - Private
# 3956    TX  Acute Care Hospitals               Voluntary non-profit - Private
# 3957    TX  Acute Care Hospitals               Voluntary non-profit - Private
# 3958    TX  Acute Care Hospitals  Government - Hospital District or Authority
# ...    ...                   ...                                          ...
# 4803    TX  Acute Care Hospitals                                  Proprietary
# 4804    TX  Acute Care Hospitals                                  Proprietary
# 4805    TX  Acute Care Hospitals  Government - Hospital District or Authority
# 4806    TX  Acute Care Hospitals                                  Proprietary
# 4807    TX  Acute Care Hospitals                                  Proprietary
#
# [411 rows x 3 columns]

# %%
df[["Hospital Name","Timeliness of care national comparison footnote"]].dropna()
# Out:
#                           Hospital Name  \
# 83    NORTH ALABAMA SPECIALITY HOSPITAL
# 84           WASHINGTON COUNTY HOSPITAL
# 85                     RED BAY HOSPITAL
# 86             CHOCTAW GENERAL HOSPITAL
# 87                   ST VINCENTS BLOUNT
# ...                                 ...
# 4807               FIRST TEXAS HOSPITAL
# 4808        LBJ TROPICAL MEDICAL CENTER
# 4809   GUAM MEMORIAL HOSPITAL AUTHORITY
# 4810         GUAM REGIONAL MEDICAL CITY
# 4811         COMMONWEALTH HEALTH CENTER
#
#         Timeliness of care national comparison footnote
# 83    Data are shown only for hospitals that partici...
# 84    Data are shown only for hospitals that partici...
# 85    Results are not available for this reporting p...
# 86    Results are not available for this reporting p...
# 87    Results are not available for this reporting p...
# ...                                                 ...
# 4807  Results are not available for this reporting p...
# ...

# %%
df.loc[(df["Hospital Type"]=="Acute Care Hospitals")&(df["Hospital overall rating"]=="4")]
# Out:
#       Provider ID                                      Hospital Name  \
# 10          10021                                DALE MEDICAL CENTER
# 11          10022                            CHEROKEE MEDICAL CENTER
# 14          10029                        EAST ALABAMA MEDICAL CENTER
# 15          10032                                   WEDOWEE HOSPITAL
# 17          10034                             COMMUNITY HOSPITAL INC
# ...           ...                                                ...
# 4777       670078                         BAPTIST EMERGENCY HOSPITAL
# 4779       670080                SETON MEDICAL CENTER HARKER HEIGHTS
# 4780       670082   BAYLOR SCOTT AND WHITE  MEDICAL CENTER  MCKINNEY
# 4782       670085    TEXAS HEALTH HARRIS METHODIST HOSPITAL ALLIANCE
# 4784       670088  BAYLOR SCOTT & WHITE MEDICAL CENTER- COLLEGE S...
#
#                              Address             City State  ZIP Code  \
# ...

# %%
df.columns
# Out:
# Index(['Provider ID', 'Hospital Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership',
#        'Emergency Services', 'Meets criteria for meaningful use of EHRs',
#        'Hospital overall rating', 'Hospital overall rating footnote',
#        'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
#        'Readmission national comparison',
#        'Readmission national comparison footnote',
#        'Patient experience national comparison',
#        'Patient experience national comparison footnote',
#        'Effectiveness of care national comparison',
#        'Effectiveness of care national comparison footnote',
#        'Timeliness of care national comparison',
#        'Timeliness of care national comparison footnote',
# ...

# %%
df["Safety of care national comparison"]
# Out:
# 0         Above the national average
# 1       Same as the national average
# 2       Same as the national average
# 3                      Not Available
# 4                      Not Available
#                     ...
# 4807                   Not Available
# 4808                   Not Available
# 4809                   Not Available
# 4810                   Not Available
# 4811                   Not Available
# Name: Safety of care national comparison, Length: 4812, dtype: object

# %%
df[["Patient experience national comparison","Provider ID"]]
# Out:
#      Patient experience national comparison  Provider ID
# 0                Below the national average        10001
# 1              Same as the national average        10005
# 2                Below the national average        10006
# 3              Same as the national average        10007
# 4                             Not Available        10008
# ...                                     ...          ...
# 4807                          Not Available       670118
# 4808                          Not Available       640001
# 4809                          Not Available       650001
# 4810                          Not Available       650003
# 4811                          Not Available       660001
#
# [4812 rows x 2 columns]

# %%
set(df["Patient experience national comparison"])
# Out:
# {'Above the national average',
#  'Below the national average',
#  'Not Available',
#  'Same as the national average'}

# %%
df[["Hospital Type","Safety of care national comparison"]]
# Out:
#              Hospital Type Safety of care national comparison
# 0     Acute Care Hospitals         Above the national average
# 1     Acute Care Hospitals       Same as the national average
# 2     Acute Care Hospitals       Same as the national average
# 3     Acute Care Hospitals                      Not Available
# 4     Acute Care Hospitals                      Not Available
# ...                    ...                                ...
# 4807  Acute Care Hospitals                      Not Available
# 4808  Acute Care Hospitals                      Not Available
# 4809  Acute Care Hospitals                      Not Available
# 4810  Acute Care Hospitals                      Not Available
# 4811  Acute Care Hospitals                      Not Available
#
# [4812 rows x 2 columns]

# %%
set(df["Hospital Type"])
# Out:
# {'Acute Care Hospitals', 'Childrens', 'Critical Access Hospitals'}

# %%
df.loc[(df["Safety of care national comparison"]=="Not Available")]["Hospital Type"].value_counts()
# Out:
# Critical Access Hospitals    1342
# Acute Care Hospitals          727
# Childrens                      99
# Name: Hospital Type, dtype: int64

# %%
df.loc[(df["Safety of care national comparison"]=="Not Available")]["Hospital Type"].value_counts()[0]
# Out:
# 1342

# %% [markdown]
# # End of skilling 3
